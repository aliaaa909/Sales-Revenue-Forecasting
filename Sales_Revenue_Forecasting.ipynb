# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Module import**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# #**Data Load**

# %%
advert = pd.read_csv('/content/Salinan advertising.csv')
advert.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-76e05c54198a> in <cell line: 0>()
# ----> 1 advert = pd.read_csv('/content/Salinan advertising.csv')
#       2 advert.info()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
advert.head()

# %% [markdown]
# **What we wanted to predict :**
#
# seberapa besar penjualan produk berdasarkan metode periklanan yang dilakukan**

# %% [markdown]
# #**Exploratory Data Analysis**

# %%
#check the relationship between features and response

sns.pairplot(advert, x_vars=['TV', 'Radio' , 'Newspaper' ],
             y_vars='Sales', height=7, aspect=0.7)

# %% [markdown]
# from the graphic, we can see that the best relationship between sales improvement and te features is tv and radio, so , for the next step we will using those features to create the best model we can use

# %% [markdown]
# #**Adjusted R Squared**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lnr = LinearRegression().fit[X['Tv', 'Newspaper'], y]
lnr_preds = lnr.predict([x[['Tv', 'Newspaper']]])

r_squared = r2_score(y, lnr_predis)
adjusted_x_squared = 1  - (lnr_squared)*(len(y)-1)/(len(y)-x.shape[1]-1)
print("adjusted r*2 : ", adjusted_x_squared)
